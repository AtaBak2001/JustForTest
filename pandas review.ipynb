# %%
import pandas as pd

# %%
cars = pd.Series(["Aston Martin", "Maclaren", "Lamborgini"])
cars
# Out:
# 0    Aston Martin
# 1        Maclaren
# 2      Lamborgini
# dtype: object

# %%
colours = pd.Series(["white","black","Red"])
colours
# Out:
# 0    white
# 1    black
# 2      Red
# dtype: object

# %%
car_data = pd.DataFrame({"car models": cars,"colour": colours})
car_data
# Out:
#      car models colour
# 0  Aston Martin  white
# 1      Maclaren  black
# 2    Lamborgini    Red

# %%
car_sales = pd.read_csv("car-sales-extended.csv")
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car_sales.to_csv("exported-car-sales-extended.csv")

# %%
ex_car_sales = pd.read_csv("exported-car-sales-extended.csv")
ex_car_sales
# Out:
#      Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price
# 0             0   Honda  White          35431      4  15323
# 1             1     BMW   Blue         192714      5  19943
# 2             2   Honda  White          84714      4  28343
# 3             3  Toyota  White         154365      4  13434
# 4             4  Nissan   Blue         181577      3  14043
# ..          ...     ...    ...            ...    ...    ...
# 995         995  Toyota  Black          35820      4  32042
# 996         996  Nissan  White         155144      3   5716
# 997         997  Nissan   Blue          66604      4  31570
# 998         998   Honda  White         215883      4   4001
# 999         999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 6 columns]

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales_columns = car_sales.columns
car_sales_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
car_sales.describe()
# Out:
#        Odometer (KM)        Doors         Price
# count    1000.000000  1000.000000   1000.000000
# mean   131073.708000     4.014000  16045.665000
# std     68859.723885     0.379405   8630.794219
# min     10148.000000     3.000000   2796.000000
# 25%     71238.000000     4.000000   9481.500000
# 50%    131202.000000     4.000000  14264.000000
# 75%    192372.750000     4.000000  20738.750000
# max    249860.000000     5.000000  52458.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           1000 non-null   object
#  1   Colour         1000 non-null   object
#  2   Odometer (KM)  1000 non-null   int64
#  3   Doors          1000 non-null   int64
#  4   Price          1000 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
car_sales["Price"].mean()
# Out:
# 16045.665

# %%
car_sales["Doors"].sum()
# Out:
# 4014

# %%
len(car_sales)
# Out:
# 1000

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
car_sales.tail(4)
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732

# %%
series = pd.Series(["dog", "cat", "monkey", "human", "goose"],
                   index = [1,2,3,2,5])

# %%
series
# Out:
# 1       dog
# 2       cat
# 3    monkey
# 2     human
# 5     goose
# dtype: object

# %%
series.loc[2]
# Out:
# 2      cat
# 2    human
# dtype: object

# %%
series.iloc[2]
# Out:
# 'monkey'

# %%
car_sales.iloc[0:4]
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car_sales["Make"]
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996    Nissan
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales[car_sales["Make"] == "Nissan"]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 4    Nissan   Blue         181577      3  14043
# 8    Nissan  White         130538      4   9374
# 10   Nissan  White         167421      4  16259
# 11   Nissan  Green          17119      4   6160
# 12   Nissan  White         102303      4  16909
# ..      ...    ...            ...    ...    ...
# 984  Nissan   Blue         157235      4   4196
# 988  Nissan  Black         248736      4   8358
# 993  Nissan  Black         162523      4   4696
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
#
# [198 rows x 5 columns]

# %%
car_sales[car_sales["Price"] > 20000]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 2     Honda  White          84714      4  28343
# 5     Honda    Red          42652      4  23883
# 7     Honda  White          43120      4  20306
# 9     Honda   Blue          51029      4  26683
# 16   Toyota    Red          96742      4  34465
# ..      ...    ...            ...    ...    ...
# 986   Honda  White          71934      4  26882
# 992   Honda  Green          54721      4  27419
# 994     BMW   Blue         163322      3  31666
# 995  Toyota  Black          35820      4  32042
# 997  Nissan   Blue          66604      4  31570
#
# [274 rows x 5 columns]

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors    3    4   5
# Make
# BMW     21    0  79
# Honda    0  304   0
# Nissan  44  154   0
# Toyota   0  398   0

# %%
car_sales.groupby(["Make","Colour"]).mean(1)
# Out:
#                Odometer (KM)     Doors         Price
# Make   Colour
# BMW    Black   147689.625000  4.250000  24706.000000
#        Blue    113372.088235  4.294118  28845.058824
#        Green   148823.500000  5.000000  19438.750000
#        Red     119749.076923  5.000000  22510.230769
#        White   123529.351351  4.675676  29255.675676
# Honda  Black   142991.437500  4.000000  13926.031250
#        Blue    130140.076923  4.000000  14107.019231
#        Green   121674.888889  4.000000  17320.444444
#        Red     116423.692308  4.000000  15180.615385
#        White   117512.209677  4.000000  14460.403226
# Nissan Black   143084.866667  4.000000  13601.000000
#        Blue    135848.250000  3.716667  14078.483333
#        Green   148961.250000  3.687500  12509.562500
#        Red     138290.500000  3.722222  13069.166667
#        White   130958.696629  3.808989  13710.505618
# Toyota Black   121501.045455  4.000000  16680.750000
# ...

# %%
car_sales["Price"].plot();

# %%
import matplotlib.pyplot as plt
car_sales["Price"].hist();

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
car = pd.read_csv("21708170-car-sales[UdemyIran.Com].csv")
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car["Price"] = car["Price"].str.replace('[\$\,\.]', '',regex=True).astype(int)
car.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int32
# dtype: object

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car["Price"] = car["Price"] / 100

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car["Price"].plot()
# Out:
# <Axes: >

# %%
car["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"].str.lower()
# Out:
# 0       honda
# 1         bmw
# 2       honda
# 3      toyota
# 4      nissan
#         ...
# 995    toyota
# 996    nissan
# 997    nissan
# 998     honda
# 999    toyota
# Name: Make, Length: 1000, dtype: object

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car["Make"] = car["Make"].str.lower()
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing[10:20]
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 10  Nissan  White       167421.0    4.0  16259.0
# 11  Nissan  Green        17119.0    4.0   6160.0
# 12  Nissan  White       102303.0    4.0  16909.0
# 13     NaN  White       134181.0    4.0  11121.0
# 14   Honda   Blue       199833.0    4.0  18946.0
# 15  Toyota   Blue       205592.0    4.0  16290.0
# 16  Toyota    Red        96742.0    4.0  34465.0
# 17     BMW  White       194189.0    5.0  17177.0
# 18  Nissan  White        67991.0    3.0   9109.0
# 19  Nissan   Blue       215820.0    4.0   6010.0

# %%
car_sales_missing.dtypes
# Out:
# Make              object
# Colour            object
# Odometer (KM)    float64
# Doors            float64
# Price            float64
# dtype: object

# %%
car_sales_missing.describe()
# Out:
#        Odometer (KM)       Doors         Price
# count     950.000000  950.000000    950.000000
# mean   131253.237895    4.011579  16042.814737
# std     69094.857187    0.382539   8581.695036
# min     10148.000000    3.000000   2796.000000
# 25%     70391.250000    4.000000   9529.250000
# 50%    131821.000000    4.000000  14297.000000
# 75%    192668.500000    4.000000  20806.250000
# max    249860.000000    5.000000  52458.000000

# %%
car_sales_missing["Odometer (KM)"] = car_sales_missing["Odometer (KM)"].fillna(car_sales_missing["Odometer (KM)"].mean())

# %%
car_sales_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  1000 non-null   float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %%
car_sales_missing_dropna = car_sales_missing.dropna()
car_sales_missing_dropna
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [815 rows x 5 columns]

# %%
seats_column = pd.Series([5,5,5,5,5])
car["seats"] = seats_column

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car["seats"].fillna(5, inplace = True)
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
fule_kilometer = [1.4,4.6,6.0,8.0,5.3,3.4,5.9,6.9,8.4,3.3]
car["fule use for (km)"] = fule_kilometer
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fule use for (km)
# 0  toyota  White         150043      4   4000.0    5.0                1.4
# 1   honda    Red          87899      4   5000.0    5.0                4.6
# 2  toyota   Blue          32549      3   7000.0    5.0                6.0
# 3     bmw  Black          11179      5  22000.0    5.0                8.0
# 4  nissan  White         213095      4   3500.0    5.0                5.3
# 5  toyota  Green          99213      4   4500.0    5.0                3.4
# 6   honda   Blue          45698      4   7500.0    5.0                5.9
# 7   honda   Blue          54738      4   7000.0    5.0                6.9
# 8  toyota  White          60000      4   6250.0    5.0                8.4
# 9  nissan  White          31600      4   9700.0    5.0                3.3

# %%
car["Total fule use"] = car["Odometer (KM)"] /100 * car["fule use for (km)"]
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fule use for (km)  \
# 0  toyota  White         150043      4   4000.0    5.0                1.4
# 1   honda    Red          87899      4   5000.0    5.0                4.6
# 2  toyota   Blue          32549      3   7000.0    5.0                6.0
# 3     bmw  Black          11179      5  22000.0    5.0                8.0
# 4  nissan  White         213095      4   3500.0    5.0                5.3
# 5  toyota  Green          99213      4   4500.0    5.0                3.4
# 6   honda   Blue          45698      4   7500.0    5.0                5.9
# 7   honda   Blue          54738      4   7000.0    5.0                6.9
# 8  toyota  White          60000      4   6250.0    5.0                8.4
# 9  nissan  White          31600      4   9700.0    5.0                3.3
#
#    Total fule use
# 0        2100.602
# 1        4043.354
# 2        1952.940
# 3         894.320
# 4       11294.035
# 5        3373.242
# ...

# %%
car["weels number"] = 4
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fule use for (km)  \
# 0  toyota  White         150043      4   4000.0    5.0                1.4
# 1   honda    Red          87899      4   5000.0    5.0                4.6
# 2  toyota   Blue          32549      3   7000.0    5.0                6.0
# 3     bmw  Black          11179      5  22000.0    5.0                8.0
# 4  nissan  White         213095      4   3500.0    5.0                5.3
# 5  toyota  Green          99213      4   4500.0    5.0                3.4
# 6   honda   Blue          45698      4   7500.0    5.0                5.9
# 7   honda   Blue          54738      4   7000.0    5.0                6.9
# 8  toyota  White          60000      4   6250.0    5.0                8.4
# 9  nissan  White          31600      4   9700.0    5.0                3.3
#
#    Total fule use  weels number
# 0        2100.602             4
# 1        4043.354             4
# 2        1952.940             4
# ...

# %%
car["safty"] = True
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fule use for (km)  \
# 0  toyota  White         150043      4   4000.0    5.0                1.4
# 1   honda    Red          87899      4   5000.0    5.0                4.6
# 2  toyota   Blue          32549      3   7000.0    5.0                6.0
# 3     bmw  Black          11179      5  22000.0    5.0                8.0
# 4  nissan  White         213095      4   3500.0    5.0                5.3
# 5  toyota  Green          99213      4   4500.0    5.0                3.4
# 6   honda   Blue          45698      4   7500.0    5.0                5.9
# 7   honda   Blue          54738      4   7000.0    5.0                6.9
# 8  toyota  White          60000      4   6250.0    5.0                8.4
# 9  nissan  White          31600      4   9700.0    5.0                3.3
#
#    Total fule use  weels number  safty
# 0        2100.602             4   True
# 1        4043.354             4   True
# ...

# %%
car.dtypes
# Out:
# Make                  object
# Colour                object
# Odometer (KM)          int64
# Doors                  int64
# Price                float64
# seats                float64
# fule use for (km)    float64
# Total fule use       float64
# weels number           int64
# safty                   bool
# dtype: object

# %%
car["gonna drop"] = car["seats"]
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fule use for (km)  \
# 0  toyota  White         150043      4   4000.0    5.0                1.4
# 1   honda    Red          87899      4   5000.0    5.0                4.6
# 2  toyota   Blue          32549      3   7000.0    5.0                6.0
# 3     bmw  Black          11179      5  22000.0    5.0                8.0
# 4  nissan  White         213095      4   3500.0    5.0                5.3
# 5  toyota  Green          99213      4   4500.0    5.0                3.4
# 6   honda   Blue          45698      4   7500.0    5.0                5.9
# 7   honda   Blue          54738      4   7000.0    5.0                6.9
# 8  toyota  White          60000      4   6250.0    5.0                8.4
# 9  nissan  White          31600      4   9700.0    5.0                3.3
#
#    Total fule use  weels number  safty  gonna drop
# 0        2100.602             4   True         5.0
# 1        4043.354             4   True         5.0
# ...

# %%
car.drop("gonna drop",axis = 1,inplace = True)
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fule use for (km)  \
# 0  toyota  White         150043      4   4000.0    5.0                1.4
# 1   honda    Red          87899      4   5000.0    5.0                4.6
# 2  toyota   Blue          32549      3   7000.0    5.0                6.0
# 3     bmw  Black          11179      5  22000.0    5.0                8.0
# 4  nissan  White         213095      4   3500.0    5.0                5.3
# 5  toyota  Green          99213      4   4500.0    5.0                3.4
# 6   honda   Blue          45698      4   7500.0    5.0                5.9
# 7   honda   Blue          54738      4   7000.0    5.0                6.9
# 8  toyota  White          60000      4   6250.0    5.0                8.4
# 9  nissan  White          31600      4   9700.0    5.0                3.3
#
#    Total fule use  weels number  safty
# 0        2100.602             4   True
# 1        4043.354             4   True
# ...
